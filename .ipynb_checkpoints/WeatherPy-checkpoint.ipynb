# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json

from api_keys import api_key

from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

units = "metric"

# %%
# List for holding lat_lngs and cities

cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
# Create tuples of lats and lngs
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    # lat_lng[0] - latitude
    # lat_lng[1] - longitude
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        
len(cities)
# Out:
# 771

# %%
cities_df = pd.DataFrame({"City": cities})
cities_df['Cloudiness']= ""
cities_df['Country']= ""
cities_df['Date']= ""
cities_df['Humidity']= ""
cities_df['Lat']= ""
cities_df['Lng']= ""
cities_df['Max Temp']= ""
cities_df['Wind Speed']= ""

cities_df.head()
# Out:
#         City Cloudiness Country Date Humidity Lat Lng Max Temp Wind Speed
# 0    mataura
# 1  bengkalis
# 2     beyneu
# 3   evanston
# 4  guangshui

# %%
base_url = "http://api.openweathermap.org/data/2.5/weather?appid={0}&q={1}&units={2}"
base_url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?appid={0}&q={1}&units={2}'

# %%
for index, row in cities_df.iterrows():
    city_url = base_url.format(api_key, row['City'], units)
    city_request = requests.get(city_url).json()
    
    try:
        
        cities_df.loc[index, 'Cloudiness'] = city_request['clouds']['all']
        cities_df.loc[index, 'Country'] = city_request['sys']['country']
        cities_df.loc[index, 'Date'] = city_request['dt']
        cities_df.loc[index, 'Humidity'] = city_request['main']['humidity']
        cities_df.loc[index, 'Lat'] = city_request['coord']['lat']
        cities_df.loc[index, 'Lng'] = city_request['coord']['lon']
        cities_df.loc[index, 'Max Temp'] = city_request['main']['temp_max']
        cities_df.loc[index, 'Wind Speed'] = city_request['wind']['speed']
        
        print("Processing Record " + str(index+1) + " | " + str(row['City']))
   
    except(KeyError, IndexError):
        print("City not found. Skipping...")
# Out:
# Processing Record 1 | mataura
# City not found. Skipping...
# Processing Record 3 | beyneu
# Processing Record 4 | evanston
# Processing Record 5 | guangshui
# Processing Record 6 | salalah
# Processing Record 7 | san patricio
# Processing Record 8 | berlevag
# Processing Record 9 | ponta do sol
# Processing Record 10 | hobart
# Processing Record 11 | amantea
# Processing Record 12 | punta arenas
# Processing Record 13 | longyearbyen
# Processing Record 14 | bredasdorp
# Processing Record 15 | cap malheureux
# Processing Record 16 | hermanus
# Processing Record 17 | avarua
# Processing Record 18 | merauke
# Processing Record 19 | vestmanna
# City not found. Skipping...
# Processing Record 21 | shuangcheng
# Processing Record 22 | dikson
# Processing Record 23 | chokurdakh
# Processing Record 24 | kapenguria
# Processing Record 25 | bonthe
# Processing Record 26 | tabas
# Processing Record 27 | hofn
# Processing Record 28 | yellowknife
# Processing Record 29 | ormara
# Processing Record 30 | nikolskoye
# Processing Record 31 | albany
# Processing Record 32 | qaanaaq
# Processing Record 33 | barrow
# Processing Record 34 | sitka
# Processing Record 35 | nouadhibou
# Processing Record 36 | mar del plata
# City not found. Skipping...
# Processing Record 38 | busselton
# Processing Record 39 | banda aceh
# Processing Record 40 | sangar
# City not found. Skipping...
# Processing Record 42 | bazarnyye mataki
# Processing Record 43 | talnakh
# Processing Record 44 | esfarayen
# Processing Record 45 | atuona
# Processing Record 46 | kodiak
# Processing Record 47 | khatanga
# Processing Record 48 | kibara
# Processing Record 49 | crotone
# Processing Record 50 | bethel
# Processing Record 51 | ushuaia
# City not found. Skipping...
# Processing Record 53 | adrar
# City not found. Skipping...
# Processing Record 55 | pevek
# Processing Record 56 | mount isa
# Processing Record 57 | saint anthony
# Processing Record 58 | pangnirtung
# Processing Record 59 | arraial do cabo
# City not found. Skipping...
# Processing Record 61 | butaritari
# Processing Record 62 | mana
# Processing Record 63 | port blair
# Processing Record 64 | rikitea
# Processing Record 65 | puerto ayora
# City not found. Skipping...
# Processing Record 67 | sorong
# Processing Record 68 | quatre cocos
# Processing Record 69 | bluff
# Processing Record 70 | kavieng
# Processing Record 71 | vila velha
# Processing Record 72 | new norfolk
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 75 | tuktoyaktuk
# Processing Record 76 | mehamn
# Processing Record 77 | hilo
# Processing Record 78 | herbrechtingen
# Processing Record 79 | north auburn
# Processing Record 80 | nyurba
# Processing Record 81 | ilyich
# Processing Record 82 | hasaki
# Processing Record 83 | petrov val
# City not found. Skipping...
# Processing Record 85 | lagoa
# Processing Record 86 | belmonte
# Processing Record 87 | esperance
# Processing Record 88 | ucluelet
# Processing Record 89 | cilegon
# City not found. Skipping...
# Processing Record 91 | aktanysh
# Processing Record 92 | orocue
# Processing Record 93 | cherskiy
# Processing Record 94 | katsuura
# Processing Record 95 | vaini
# Processing Record 96 | jamestown
# Processing Record 97 | port alfred
# Processing Record 98 | chuy
# Processing Record 99 | port macquarie
# Processing Record 100 | ishigaki
# Processing Record 101 | sao filipe
# Processing Record 102 | qaqortoq
# Processing Record 103 | ewa beach
# Processing Record 104 | locri
# Processing Record 105 | viedma
# Processing Record 106 | eyl
# Processing Record 107 | vila franca do campo
# Processing Record 108 | juarez
# Processing Record 109 | georgetown
# Processing Record 110 | klaksvik
# Processing Record 111 | northam
# City not found. Skipping...
# Processing Record 113 | boyolangu
# Processing Record 114 | villarrica
# Processing Record 115 | macklin
# Processing Record 116 | kibala
# Processing Record 117 | pangody
# Processing Record 118 | shawinigan
# City not found. Skipping...
# Processing Record 120 | tezu
# Processing Record 121 | vostok
# Processing Record 122 | norman wells
# Processing Record 123 | nome
# Processing Record 124 | ilulissat
# Processing Record 125 | provideniya
# Processing Record 126 | huambo
# Processing Record 127 | husavik
# City not found. Skipping...
# Processing Record 129 | lima
# Processing Record 130 | madaoua
# Processing Record 131 | kungurtug
# Processing Record 132 | altay
# Processing Record 133 | teguise
# Processing Record 134 | ust-ishim
# Processing Record 135 | tuatapere
# Processing Record 136 | saldanha
# City not found. Skipping...
# Processing Record 138 | isiro
# Processing Record 139 | kapaa
# Processing Record 140 | mandalgovi
# Processing Record 141 | kargopol
# Processing Record 142 | port elizabeth
# Processing Record 143 | namtsy
# Processing Record 144 | mahebourg
# Processing Record 145 | sanmenxia
# Processing Record 146 | saskylakh
# City not found. Skipping...
# Processing Record 148 | castro
# City not found. Skipping...
# Processing Record 150 | lesnikovo
# Processing Record 151 | kansanshi
# Processing Record 152 | pedernales
# Processing Record 153 | praia da vitoria
# Processing Record 154 | okhotsk
# Processing Record 155 | torbay
# Processing Record 156 | veraval
# Processing Record 157 | charyshskoye
# Processing Record 158 | tiarei
# Processing Record 159 | tyumentsevo
# Processing Record 160 | yumen
# Processing Record 161 | graham
# Processing Record 162 | davidson
# Processing Record 163 | nanortalik
# City not found. Skipping...
# Processing Record 165 | bubaque
# Processing Record 166 | aranos
# Processing Record 167 | lindi
# Processing Record 168 | buin
# Processing Record 169 | nizhniy tsasuchey
# Processing Record 170 | port lincoln
# Processing Record 171 | avera
# Processing Record 172 | zaranj
# Processing Record 173 | benguela
# Processing Record 174 | umm kaddadah
# Processing Record 175 | auburn
# Processing Record 176 | east london
# City not found. Skipping...
# Processing Record 178 | geraldton
# Processing Record 179 | palauig
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 182 | hirara
# Processing Record 183 | lompoc
# Processing Record 184 | upernavik
# Processing Record 185 | kitimat
# Processing Record 186 | ribeira grande
# Processing Record 187 | aasiaat
# Processing Record 188 | bethal
# Processing Record 189 | tasiilaq
# Processing Record 190 | saint-pierre
# City not found. Skipping...
# Processing Record 192 | mezen
# City not found. Skipping...
# Processing Record 194 | el monte
# Processing Record 195 | standerton
# Processing Record 196 | gizo
# Processing Record 197 | cururupu
# Processing Record 198 | bathsheba
# Processing Record 199 | zaysan
# Processing Record 200 | ancud
# Processing Record 201 | chapais
# Processing Record 202 | altamira
# City not found. Skipping...
# Processing Record 204 | pathein
# Processing Record 205 | jericho
# Processing Record 206 | saint-philippe
# Processing Record 207 | qasigiannguit
# Processing Record 208 | bikin
# Processing Record 209 | lerwick
# Processing Record 210 | lakatoro
# Processing Record 211 | laguna
# Processing Record 212 | cabo san lucas
# Processing Record 213 | faanui
# Processing Record 214 | puerto madryn
# Processing Record 215 | guerrero negro
# Processing Record 216 | muroto
# Processing Record 217 | afikpo
# City not found. Skipping...
# Processing Record 219 | turan
# Processing Record 220 | kuusamo
# Processing Record 221 | san cristobal
# Processing Record 222 | cayenne
# Processing Record 223 | urubamba
# Processing Record 224 | winnemucca
# Processing Record 225 | tiksi
# Processing Record 226 | tiznit
# Processing Record 227 | nagato
# Processing Record 228 | richards bay
# Processing Record 229 | dingle
# Processing Record 230 | cape town
# City not found. Skipping...
# Processing Record 232 | tarauaca
# Processing Record 233 | lamu
# Processing Record 234 | raudeberg
# Processing Record 235 | kahului
# City not found. Skipping...
# Processing Record 237 | makakilo city
# Processing Record 238 | fairbanks
# Processing Record 239 | havoysund
# Processing Record 240 | thompson
# Processing Record 241 | saint george
# Processing Record 242 | nishihara
# Processing Record 243 | mocuba
# Processing Record 244 | ornes
# Processing Record 245 | rawson
# Processing Record 246 | hovd
# Processing Record 247 | lavrentiya
# Processing Record 248 | itamarandiba
# Processing Record 249 | lebu
# Processing Record 250 | maniitsoq
# City not found. Skipping...
# Processing Record 252 | kaitangata
# City not found. Skipping...
# Processing Record 254 | papenburg
# Processing Record 255 | anyang
# Processing Record 256 | isla vista
# Processing Record 257 | tsaratanana
# Processing Record 258 | narasannapeta
# Processing Record 259 | taoudenni
# Processing Record 260 | clyde river
# Processing Record 261 | juegang
# City not found. Skipping...
# Processing Record 263 | bilibino
# Processing Record 264 | padang
# Processing Record 265 | changtu
# Processing Record 266 | esmeraldas
# Processing Record 267 | plettenberg bay
# Processing Record 268 | jalu
# Processing Record 269 | cockburn town
# Processing Record 270 | letterkenny
# Processing Record 271 | wadena
# Processing Record 272 | nizhniy tagil
# Processing Record 273 | heihe
# Processing Record 274 | ketchikan
# Processing Record 275 | ndungu
# Processing Record 276 | buraydah
# City not found. Skipping...
# Processing Record 278 | gisborne
# City not found. Skipping...
# Processing Record 280 | forssa
# Processing Record 281 | solnechnyy
# Processing Record 282 | port-gentil
# Processing Record 283 | aswan
# Processing Record 284 | kruisfontein
# Processing Record 285 | celestun
# Processing Record 286 | namibe
# Processing Record 287 | dzilam gonzalez
# City not found. Skipping...
# Processing Record 289 | aksarka
# Processing Record 290 | kayerkan
# Processing Record 291 | impfondo
# Processing Record 292 | robertsganj
# Processing Record 293 | arrifes
# Processing Record 294 | sao paulo de olivenca
# Processing Record 295 | mahajanga
# Processing Record 296 | los llanos de aridane
# City not found. Skipping...
# Processing Record 298 | hudson bay
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 301 | inhambane
# Processing Record 302 | san andres
# Processing Record 303 | bosaso
# Processing Record 304 | carnarvon
# Processing Record 305 | prata
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 308 | bjornevatn
# Processing Record 309 | khandyga
# Processing Record 310 | plouzane
# Processing Record 311 | vazhiny
# Processing Record 312 | te anau
# Processing Record 313 | tazmalt
# Processing Record 314 | fortuna
# Processing Record 315 | mahibadhoo
# Processing Record 316 | westport
# Processing Record 317 | coquimbo
# Processing Record 318 | klyuchevskiy
# City not found. Skipping...
# Processing Record 320 | shitanjing
# Processing Record 321 | pedasi
# City not found. Skipping...
# Processing Record 323 | constitucion
# Processing Record 324 | tunduma
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 327 | basseterre
# City not found. Skipping...
# Processing Record 329 | mount gambier
# Processing Record 330 | antalaha
# Processing Record 331 | nogliki
# Processing Record 332 | dehloran
# Processing Record 333 | inyonga
# Processing Record 334 | vung tau
# Processing Record 335 | tommot
# Processing Record 336 | linhares
# Processing Record 337 | mawlaik
# Processing Record 338 | cidreira
# Processing Record 339 | paamiut
# City not found. Skipping...
# Processing Record 341 | farsund
# Processing Record 342 | komsomolskiy
# Processing Record 343 | kem
# City not found. Skipping...
# Processing Record 345 | pinega
# Processing Record 346 | victoria
# City not found. Skipping...
# Processing Record 348 | acapulco
# Processing Record 349 | antofagasta
# Processing Record 350 | evensk
# Processing Record 351 | kupang
# Processing Record 352 | nova soure
# Processing Record 353 | kendari
# Processing Record 354 | ejido
# City not found. Skipping...
# Processing Record 356 | nemuro
# Processing Record 357 | noumea
# Processing Record 358 | alcains
# Processing Record 359 | codrington
# Processing Record 360 | tucuman
# Processing Record 361 | banepa
# Processing Record 362 | aksu
# Processing Record 363 | calama
# Processing Record 364 | severo-kurilsk
# Processing Record 365 | itoman
# Processing Record 366 | tshikapa
# Processing Record 367 | songjianghe
# City not found. Skipping...
# Processing Record 369 | ouegoa
# Processing Record 370 | yulara
# Processing Record 371 | yarim
# Processing Record 372 | nioro
# Processing Record 373 | flinders
# Processing Record 374 | bowen
# Processing Record 375 | ballina
# Processing Record 376 | atar
# Processing Record 377 | omboue
# Processing Record 378 | luderitz
# Processing Record 379 | ankazobe
# Processing Record 380 | altamont
# Processing Record 381 | lokosovo
# City not found. Skipping...
# Processing Record 383 | abonnema
# Processing Record 384 | pingyin
# Processing Record 385 | itupiranga
# Processing Record 386 | jian
# Processing Record 387 | mareeba
# City not found. Skipping...
# Processing Record 389 | virginia beach
# Processing Record 390 | jember
# Processing Record 391 | alta floresta
# Processing Record 392 | karaton
# Processing Record 393 | sharjah
# City not found. Skipping...
# Processing Record 395 | bonavista
# Processing Record 396 | manbij
# Processing Record 397 | bambous virieux
# Processing Record 398 | soyo
# Processing Record 399 | catanzaro
# Processing Record 400 | alvorada
# Processing Record 401 | hithadhoo
# City not found. Skipping...
# Processing Record 403 | huescar
# Processing Record 404 | kavaratti
# Processing Record 405 | knysna
# Processing Record 406 | tura
# Processing Record 407 | takoradi
# Processing Record 408 | monteagudo
# Processing Record 409 | arcachon
# Processing Record 410 | monte alegre
# Processing Record 411 | vuktyl
# Processing Record 412 | haines junction
# Processing Record 413 | chaman
# Processing Record 414 | ivankiv
# Processing Record 415 | lufilufi
# Processing Record 416 | hualmay
# Processing Record 417 | palanga
# Processing Record 418 | amapa
# Processing Record 419 | morada nova
# Processing Record 420 | pacifica
# Processing Record 421 | cigand
# Processing Record 422 | portland
# Processing Record 423 | santa rosa
# Processing Record 424 | naze
# City not found. Skipping...
# Processing Record 426 | naliya
# Processing Record 427 | nortelandia
# Processing Record 428 | lewistown
# Processing Record 429 | pangkalanbuun
# Processing Record 430 | nanakuli
# Processing Record 431 | colac
# Processing Record 432 | mogadishu
# Processing Record 433 | taber
# Processing Record 434 | qianjiang
# Processing Record 435 | beringovskiy
# Processing Record 436 | lang suan
# Processing Record 437 | marapanim
# Processing Record 438 | sorland
# Processing Record 439 | marsala
# Processing Record 440 | yeppoon
# City not found. Skipping...
# Processing Record 442 | shestakovo
# Processing Record 443 | saint-augustin
# Processing Record 444 | zadar
# City not found. Skipping...
# Processing Record 446 | sibolga
# Processing Record 447 | guarapari
# Processing Record 448 | kerrobert
# Processing Record 449 | unnao
# Processing Record 450 | kumluca
# Processing Record 451 | el dorado
# Processing Record 452 | marrakesh
# Processing Record 453 | sao joao da barra
# Processing Record 454 | khilok
# City not found. Skipping...
# Processing Record 456 | ambilobe
# Processing Record 457 | rapid city
# Processing Record 458 | isangel
# Processing Record 459 | mayo
# Processing Record 460 | lata
# Processing Record 461 | mapimi
# Processing Record 462 | karwar
# Processing Record 463 | maningrida
# Processing Record 464 | meulaboh
# Processing Record 465 | ulaangom
# Processing Record 466 | amazar
# Processing Record 467 | honiara
# Processing Record 468 | hokitika
# Processing Record 469 | fergus falls
# City not found. Skipping...
# Processing Record 471 | sibu
# Processing Record 472 | svetlogorsk
# City not found. Skipping...
# Processing Record 474 | ossora
# Processing Record 475 | wellingborough
# Processing Record 476 | tecoanapa
# Processing Record 477 | gat
# Processing Record 478 | santo domingo
# Processing Record 479 | kachug
# Processing Record 480 | xai-xai
# Processing Record 481 | warrington
# Processing Record 482 | mkushi
# Processing Record 483 | wajima
# Processing Record 484 | panguipulli
# Processing Record 485 | hobyo
# Processing Record 486 | hay river
# Processing Record 487 | riyadh
# Processing Record 488 | tayga
# Processing Record 489 | fairlie
# Processing Record 490 | show low
# Processing Record 491 | nalut
# City not found. Skipping...
# Processing Record 493 | hamilton
# Processing Record 494 | alice springs
# Processing Record 495 | dolores
# City not found. Skipping...
# Processing Record 497 | jinji
# Processing Record 498 | tallahassee
# Processing Record 499 | garden city
# Processing Record 500 | izmir
# City not found. Skipping...
# Processing Record 502 | acajutla
# Processing Record 503 | bozeman
# Processing Record 504 | aleksandrow kujawski
# Processing Record 505 | leningradskiy
# Processing Record 506 | ostrovnoy
# Processing Record 507 | agadez
# Processing Record 508 | vikhorevka
# City not found. Skipping...
# Processing Record 510 | souillac
# Processing Record 511 | vanimo
# Processing Record 512 | pringsewu
# City not found. Skipping...
# Processing Record 514 | tsabong
# Processing Record 515 | norsup
# Processing Record 516 | eureka
# Processing Record 517 | carbonia
# Processing Record 518 | redcar
# Processing Record 519 | muisne
# Processing Record 520 | carutapera
# Processing Record 521 | maceio
# Processing Record 522 | dohar
# Processing Record 523 | sheridan
# City not found. Skipping...
# Processing Record 525 | tilichiki
# Processing Record 526 | konevo
# Processing Record 527 | borzya
# Processing Record 528 | road town
# Processing Record 529 | kalmunai
# Processing Record 530 | metro
# Processing Record 531 | saint-leu
# Processing Record 532 | belle fourche
# Processing Record 533 | aksha
# Processing Record 534 | aykhal
# Processing Record 535 | hoquiam
# Processing Record 536 | wonthaggi
# Processing Record 537 | tautira
# Processing Record 538 | chara
# Processing Record 539 | anadyr
# Processing Record 540 | krasnogorskiy
# Processing Record 541 | narsaq
# Processing Record 542 | marzuq
# Processing Record 543 | poretskoye
# Processing Record 544 | sulphur
# Processing Record 545 | arman
# Processing Record 546 | malpura
# Processing Record 547 | arona
# Processing Record 548 | santiago
# Processing Record 549 | basco
# Processing Record 550 | kununurra
# Processing Record 551 | matara
# Processing Record 552 | latung
# Processing Record 553 | treuchtlingen
# Processing Record 554 | mount pleasant
# Processing Record 555 | pisco
# Processing Record 556 | east moline
# Processing Record 557 | kenai
# Processing Record 558 | ayni
# Processing Record 559 | sioux lookout
# Processing Record 560 | dongkan
# Processing Record 561 | zeya
# Processing Record 562 | vao
# City not found. Skipping...
# Processing Record 564 | abha
# Processing Record 565 | lakes entrance
# Processing Record 566 | buique
# Processing Record 567 | puro
# City not found. Skipping...
# Processing Record 569 | shingu
# Processing Record 570 | puerto varas
# Processing Record 571 | williamsburg
# Processing Record 572 | dunedin
# Processing Record 573 | port hedland
# Processing Record 574 | zanjan
# Processing Record 575 | mandera
# City not found. Skipping...
# Processing Record 577 | sao miguel do araguaia
# Processing Record 578 | sainte-rose
# Processing Record 579 | iracoubo
# Processing Record 580 | panama city
# Processing Record 581 | chauk
# Processing Record 582 | blue springs
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 585 | rockland
# Processing Record 586 | seoul
# Processing Record 587 | keffi
# Processing Record 588 | iqaluit
# Processing Record 589 | la ronge
# Processing Record 590 | kawalu
# Processing Record 591 | barranca
# Processing Record 592 | thinadhoo
# Processing Record 593 | labuhan
# Processing Record 594 | rexburg
# Processing Record 595 | charters towers
# Processing Record 596 | luanda
# Processing Record 597 | barmer
# Processing Record 598 | rovnoye
# Processing Record 599 | tavagnacco
# Processing Record 600 | batemans bay
# Processing Record 601 | perth
# Processing Record 602 | barra patuca
# Processing Record 603 | danville
# Processing Record 604 | lieksa
# Processing Record 605 | iraquara
# Processing Record 606 | bezhetsk
# Processing Record 607 | seoni
# Processing Record 608 | volot
# Processing Record 609 | ligayan
# Processing Record 610 | matagami
# Processing Record 611 | henties bay
# Processing Record 612 | namwala
# Processing Record 613 | santa isabel
# Processing Record 614 | pokhara
# City not found. Skipping...
# Processing Record 616 | belaya gora
# Processing Record 617 | summerville
# Processing Record 618 | rio gallegos
# Processing Record 619 | bilma
# City not found. Skipping...
# Processing Record 621 | miraflores
# Processing Record 622 | verkhoyansk
# Processing Record 623 | tuy hoa
# Processing Record 624 | shizunai
# Processing Record 625 | khasan
# Processing Record 626 | ahipara
# Processing Record 627 | novikovo
# Processing Record 628 | yaypan
# Processing Record 629 | kalianget
# Processing Record 630 | dunmore town
# Processing Record 631 | weihai
# Processing Record 632 | kudat
# City not found. Skipping...
# Processing Record 634 | guipavas
# Processing Record 635 | amga
# Processing Record 636 | haapiti
# Processing Record 637 | porbandar
# Processing Record 638 | san quintin
# Processing Record 639 | halifax
# Processing Record 640 | naberera
# City not found. Skipping...
# Processing Record 642 | koson
# Processing Record 643 | pasighat
# Processing Record 644 | iquitos
# Processing Record 645 | nyimba
# Processing Record 646 | itarema
# Processing Record 647 | san felipe
# Processing Record 648 | teeli
# Processing Record 649 | tselinnoye
# Processing Record 650 | nadym
# Processing Record 651 | beloha
# Processing Record 652 | chernaya kholunitsa
# Processing Record 653 | chimbote
# Processing Record 654 | coihaique
# Processing Record 655 | kiunga
# Processing Record 656 | bandarbeyla
# Processing Record 657 | waddan
# City not found. Skipping...
# Processing Record 659 | suba
# Processing Record 660 | fene
# Processing Record 661 | san luis
# Processing Record 662 | vila do maio
# Processing Record 663 | batavia
# Processing Record 664 | kommunisticheskiy
# Processing Record 665 | canmore
# Processing Record 666 | kovernino
# Processing Record 667 | wewak
# Processing Record 668 | marau
# Processing Record 669 | heyang
# Processing Record 670 | quibdo
# Processing Record 671 | brainerd
# City not found. Skipping...
# Processing Record 673 | luba
# Processing Record 674 | si sa ket
# Processing Record 675 | greymouth
# Processing Record 676 | hammond
# Processing Record 677 | sohag
# Processing Record 678 | sosva
# Processing Record 679 | dudinka
# Processing Record 680 | guia de isora
# Processing Record 681 | nampula
# Processing Record 682 | pacific grove
# Processing Record 683 | troy
# Processing Record 684 | wanning
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 687 | idritsa
# Processing Record 688 | bollnas
# Processing Record 689 | fabriano
# Processing Record 690 | smithers
# Processing Record 691 | camacha
# Processing Record 692 | wum
# Processing Record 693 | bay roberts
# Processing Record 694 | zhigalovo
# Processing Record 695 | tateyama
# Processing Record 696 | san jose
# Processing Record 697 | zaozerne
# Processing Record 698 | santa vitoria do palmar
# Processing Record 699 | san carlos de bariloche
# Processing Record 700 | houma
# Processing Record 701 | maxixe
# Processing Record 702 | panzhihua
# Processing Record 703 | san vicente
# Processing Record 704 | dhidhdhoo
# Processing Record 705 | kloulklubed
# Processing Record 706 | launceston
# Processing Record 707 | havre-saint-pierre
# Processing Record 708 | nantucket
# Processing Record 709 | tulle
# Processing Record 710 | chapleau
# City not found. Skipping...
# Processing Record 712 | djibo
# Processing Record 713 | englehart
# Processing Record 714 | kaspiysk
# City not found. Skipping...
# Processing Record 716 | nancha
# City not found. Skipping...
# Processing Record 718 | kamaishi
# Processing Record 719 | dubbo
# Processing Record 720 | gazimurskiy zavod
# Processing Record 721 | talakan
# Processing Record 722 | angoram
# Processing Record 723 | alofi
# Processing Record 724 | sola
# Processing Record 725 | savannah bight
# City not found. Skipping...
# Processing Record 727 | lhokseumawe
# Processing Record 728 | vardo
# Processing Record 729 | visby
# Processing Record 730 | edd
# Processing Record 731 | moundou
# Processing Record 732 | ziarat
# Processing Record 733 | kapit
# Processing Record 734 | clearwater
# Processing Record 735 | half moon bay
# Processing Record 736 | sanary-sur-mer
# Processing Record 737 | sobolevo
# Processing Record 738 | boende
# Processing Record 739 | noshiro
# Processing Record 740 | the valley
# Processing Record 741 | srednekolymsk
# Processing Record 742 | airai
# Processing Record 743 | kuopio
# Processing Record 744 | oranjemund
# Processing Record 745 | kupino
# Processing Record 746 | ouallam
# Processing Record 747 | svetlaya
# Processing Record 748 | davila
# Processing Record 749 | teguldet
# City not found. Skipping...
# Processing Record 751 | popova
# Processing Record 752 | broome
# Processing Record 753 | vitim
# Processing Record 754 | caravelas
# Processing Record 755 | san joaquin
# Processing Record 756 | kanniyakumari
# Processing Record 757 | black river
# Processing Record 758 | jizan
# Processing Record 759 | eichstatt
# Processing Record 760 | fort nelson
# Processing Record 761 | kachiry
# City not found. Skipping...
# Processing Record 763 | basay
# Processing Record 764 | tumpat
# Processing Record 765 | mitsamiouli
# Processing Record 766 | poum
# Processing Record 767 | antropovo
# Processing Record 768 | luganville
# Processing Record 769 | ripoll
# Processing Record 770 | bucak
# Processing Record 771 | balod

# %%
cities_df.count()
# Out:
# City          771
# Cloudiness    771
# Country       771
# Date          771
# Humidity      771
# Lat           771
# Lng           771
# Max Temp      771
# Wind Speed    771
# dtype: int64

# %%
cities_df = cities_df.dropna(how='any')
cities_df.count()
# Out:
# City          771
# Cloudiness    771
# Country       771
# Date          771
# Humidity      771
# Lat           771
# Lng           771
# Max Temp      771
# Wind Speed    771
# dtype: int64

# %%
cities_df.head()
# Out:
#         City Cloudiness Country        Date Humidity    Lat     Lng Max Temp  \
# 0    mataura         76      NZ  1541918950       56 -46.19  168.86    15.66
# 1  bengkalis
# 2     beyneu         92      KZ  1541918494       89  45.32   55.19     1.33
# 3   evanston         90      US  1541915700       63  42.04  -87.69     -1.1
# 4  guangshui         36      CN  1541918951       65  31.62  113.82    16.38
#
#   Wind Speed
# 0       5.97
# 1
# 2       6.62
# 3        4.1
# 4       3.02

# %%
for column in ['Cloudiness', 'Humidity', 'Lat', 'Lng', 'Max Temp', 'Wind Speed']:
    cities_df[column] = pd.to_numeric(cities_df[column])
    #print(type(cities_df[column][1]))

# %%
plt.figure(figsize=(8,5))
plt.title("City Latitude v.s. Max Temperature (11/05/18)", fontsize=18)
plt.scatter(cities_df['Lat'], 
            cities_df['Max Temp'], 
            marker='o', 
            facecolor='steelblue', 
            edgecolor='black',
            s=50, 
            alpha=0.7)
plt.xlabel("Latitude", fontsize=14)
plt.ylabel("Max Temperature (C)", fontsize=14)
plt.grid()

# %%
# Conclusion:
# The plot shows that maximum temperature reaches higher around 0 degress laitude or the equator.

# %%
plt.figure(figsize=(8,5))
plt.title("City Latitude v.s. Humidity (11/05/18)", fontsize=18)
plt.scatter(cities_df['Lat'].astype(float), 
            cities_df['Humidity'].astype(float), 
            marker='o', 
            facecolor='steelblue', 
            edgecolor='black',
            s=50, 
            alpha=0.7)
plt.xlabel("Latitude", fontsize=14)
plt.ylabel("Humidity (%)", fontsize=14)
plt.grid()

# %%
# Conclusion:
# According to plot, humidity level tends to be uniformly higher right around the equator and varies more as we move away from it.

# %%
plt.figure(figsize=(8,5))
plt.title("City Latitude v.s. Cloudiness (11/05/18)", fontsize=18)
plt.scatter(cities_df['Lat'].astype(float), 
            cities_df['Cloudiness'].astype(float), 
            marker='o', 
            facecolor='steelblue', 
            edgecolor='black',
            s=50, 
            alpha=0.7)
plt.xlabel("Latitude", fontsize=14)
plt.ylabel("Cloudiness (%)", fontsize=14)
plt.grid()

# %%
# Conclusion:
# The plot shows that the amount of clouds tends to be slightly more varied around and equater, but the difference is not very obvious.

# %%
plt.figure(figsize=(8,5))
plt.title("City Latitude v.s. Wind Speed (11/05/18)", fontsize=18)
plt.scatter(cities_df['Lat'].astype(float), 
            cities_df['Wind Speed'].astype(float), 
            marker='o', 
            facecolor='steelblue', 
            edgecolor='black',
            s=50, 
            alpha=0.7)
plt.xlabel("Latitude", fontsize=14)
plt.ylabel("Wind Speed (mph)", fontsize=14)
plt.grid()

# %%
# Conclusion: 
# According to the plot, wind is slower around the equator and picks up more speed as we move further away from it.

# %%
city_url = base_url.format(api_key, cities_df['City'][2], units)
city_request = requests.get(city_url).json()

print(json.dumps(city_request, indent=4, sort_keys=True))
# Out:
# {
#     "base": "stations",
#     "clouds": {
#         "all": 20
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -19.25,
#         "lon": 17.72
#     },
#     "dt": 1541404800,
#     "id": 3352593,
#     "main": {
#         "humidity": 36,
#         "pressure": 1021,
#         "temp": 27,
#         "temp_max": 27,
#         "temp_min": 27
#     },
#     "name": "Tsumeb",
#     "sys": {
#         "country": "NA",
#         "id": 6914,
#         "message": 0.0032,
#         "sunrise": 1541390781,
#         "sunset": 1541437154,
#         "type": 1
#     },
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02d",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 340,
#         "speed": 3.6
#     }
# }
